# %%
import pandas as pd
import numpy as np

from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv('data/clean_retail.csv')
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country Class  Price
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  high  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom   mid  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom   low  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom   low  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom   low  20.34

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10617 entries, 0 to 10616
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    10617 non-null  int64
#  1   StockCode    10617 non-null  object
#  2   Description  10617 non-null  object
#  3   Quantity     10617 non-null  int64
#  4   InvoiceDate  10617 non-null  object
#  5   UnitPrice    10617 non-null  float64
#  6   CustomerID   10617 non-null  float64
#  7   Country      10617 non-null  object
#  8   Class        10617 non-null  object
#  9   Price        10617 non-null  float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 829.6+ KB

# %%
df.describe()
# Out:
#            InvoiceNo      Quantity     UnitPrice    CustomerID         Price
# count   10617.000000  10617.000000  10617.000000  10617.000000  10617.000000
# mean   537002.568993     10.544598      3.070126  15598.064896     19.468702
# std       350.949586     45.732462      4.587039   1763.597277     55.401605
# min    536365.000000      1.000000      0.000000  12347.000000      0.000000
# 25%    536690.000000      1.000000      1.250000  14237.000000      3.750000
# 50%    537050.000000      4.000000      2.100000  15708.000000     10.000000
# 75%    537254.000000     12.000000      3.750000  17218.000000     17.700000
# max    537636.000000   2880.000000    295.000000  18239.000000   1627.200000

# %%
df.shape
# Out:
# (10617, 10)

# %%
df['Description'].value_counts()
# Out:
# HAND WARMER UNION JACK                85
# HAND WARMER SCOTTY DOG DESIGN         77
# WHITE HANGING HEART T-LIGHT HOLDER    75
# PAPER CHAIN KIT 50'S CHRISTMAS        70
# HAND WARMER OWL DESIGN                68
#                                       ..
# SET OF 2 ROUND TINS DUTCH CHEESE       1
# BATHROOM SCALES FOOTPRINTS IN SAND     1
# GLASS JAR DAISY FRESH COTTON WOOL      1
# GLASS JAR KINGS CHOICE                 1
# DECORATIVE ROSE BATHROOM BOTTLE        1
# Name: Description, Length: 1852, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# United Kingdom    9882
# Germany            197
# France             167
# EIRE               132
# Norway              73
# Lithuania           34
# Iceland             31
# Italy               24
# Japan               16
# Australia           14
# Portugal            14
# Belgium             12
# Poland               8
# Switzerland          6
# Spain                5
# Netherlands          2
# Name: Country, dtype: int64

# %%
# 공백 제거
df['Description'] = df['Description'].str.strip()

# InvoiceNo 형 변환
df['InvoiceNo'] = df['InvoiceNo'].astype('str')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10617 entries, 0 to 10616
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    10617 non-null  object
#  1   StockCode    10617 non-null  object
#  2   Description  10617 non-null  object
#  3   Quantity     10617 non-null  int64
#  4   InvoiceDate  10617 non-null  object
#  5   UnitPrice    10617 non-null  float64
#  6   CustomerID   10617 non-null  float64
#  7   Country      10617 non-null  object
#  8   Class        10617 non-null  object
#  9   Price        10617 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 829.6+ KB

# %%
# 독일 데이터만 추출
german_df = df[df['Country'] == 'Germany']
german_df.head()
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 1098    536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1099    536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 1100    536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 1101    536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 1102    536527     22244           3 HOOK HANGER MAGIC GARDEN        12
#
#           InvoiceDate  UnitPrice  CustomerID  Country Class  Price
# 1098  12/1/2010 13:04       2.95     12662.0  Germany   mid   17.7
# 1099  12/1/2010 13:04       2.55     12662.0  Germany   mid   15.3
# 1100  12/1/2010 13:04       0.85     12662.0  Germany   mid   10.2
# 1101  12/1/2010 13:04       1.65     12662.0  Germany   mid   19.8
# 1102  12/1/2010 13:04       1.95     12662.0  Germany   mid   23.4

# %%
german_df['Description'].value_counts()
# Out:
# POSTAGE                               11
# JAM MAKING SET PRINTED                 4
# JAM JAR WITH GREEN LID                 4
# JAM JAR WITH PINK LID                  4
# IVORY KITCHEN SCALES                   3
#                                       ..
# 3 PIECE SPACEBOY COOKIE CUTTER SET     1
# GUMBALL MAGAZINE RACK                  1
# DOORMAT RED RETROSPOT                  1
# ROUND CAKE TIN VINTAGE GREEN           1
# SET OF 6 STRAWBERRY CHOPSTICKS         1
# Name: Description, Length: 154, dtype: int64

# %%
# InvoiceNo : 행 // Description : 열
mybasket = german_df.groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().fillna(0)
mybasket
# Out:
# Description  3 HOOK HANGER MAGIC GARDEN  3 HOOK PHOTO SHELF ANTIQUE WHITE  \
# InvoiceNo
# 536527                             12.0                               0.0
# 536840                              0.0                               0.0
# 536861                              0.0                               0.0
# 536967                              0.0                               0.0
# 536983                              0.0                               4.0
# 537197                              0.0                               0.0
# 537198                              0.0                               0.0
# 537201                             12.0                               0.0
# 537212                              0.0                               0.0
# 537250                              0.0                               0.0
# 537594                             12.0                               0.0
#
# Description  3 PIECE SPACEBOY COOKIE CUTTER SET  \
# InvoiceNo
# 536527                                      0.0
# 536840                                      0.0
# 536861                                      0.0
# 536967                                      0.0
# 536983                                      0.0
# 537197                                      0.0
# 537198                                      0.0
# 537201                                     18.0
# 537212                                      0.0
# 537250                                      0.0
# 537594                                      0.0
#
# Description  5 HOOK HANGER MAGIC TOADSTOOL  5 HOOK HANGER RED MAGIC TOADSTOOL  \
# InvoiceNo
# 536527                                12.0                               12.0
# 536840                                 0.0                                0.0
# 536861                                 0.0                                0.0
# 536967                                 0.0                                0.0
# 536983                                 0.0                                0.0
# 537197                                 0.0                                0.0
# 537198                                 0.0                                0.0
# 537201                                12.0                                0.0
# 537212                                 0.0                                0.0
# 537250                                 0.0                                0.0
# 537594                                 0.0                                0.0
#
# Description  6 RIBBONS RUSTIC CHARM  60 CAKE CASES VINTAGE CHRISTMAS  \
# InvoiceNo
# 536527                          0.0                              0.0
# 536840                         12.0                             24.0
# 536861                         12.0                              0.0
# 536967                          0.0                              0.0
# 536983                          0.0                              0.0
# 537197                          0.0                              0.0
# 537198                          0.0                              0.0
# 537201                         24.0                              0.0
# 537212                          0.0                              0.0
# 537250                          0.0                              0.0
# 537594                          0.0                              0.0
#
# Description  60 TEATIME FAIRY CAKE CASES  ANGEL DECORATION PAINTED ZINC  \
# InvoiceNo
# 536527                               0.0                            0.0
# 536840                              24.0                            0.0
# 536861                               0.0                            0.0
# 536967                               0.0                            0.0
# 536983                               0.0                            0.0
# 537197                               0.0                            0.0
# 537198                               0.0                            0.0
# 537201                               0.0                           24.0
# 537212                               0.0                            0.0
# 537250                               0.0                            0.0
# 537594                               0.0                            0.0
#
# Description  ASSORTED COLOUR LIZARD SUCTION HOOK  ...  STARS GIFT TAPE  \
# InvoiceNo                                         ...
# 536527                                      24.0  ...              0.0
# 536840                                       0.0  ...              0.0
# 536861                                       0.0  ...              0.0
# 536967                                       0.0  ...              0.0
# 536983                                       0.0  ...              0.0
# 537197                                       0.0  ...              0.0
# 537198                                       0.0  ...              0.0
# 537201                                       0.0  ...              0.0
# 537212                                       0.0  ...             12.0
# 537250                                       0.0  ...              0.0
# 537594                                       0.0  ...              0.0
#
# Description  SWEETHEART CAKESTAND 3 TIER  TEA TIME OVEN GLOVE  \
# InvoiceNo
# 536527                               0.0                  0.0
# 536840                               1.0                  0.0
# 536861                               0.0                  0.0
# 536967                               0.0                  0.0
# 536983                               0.0                  0.0
# 537197                               0.0                  0.0
# 537198                               0.0                  0.0
# 537201                               0.0                  0.0
# 537212                               0.0                  0.0
# 537250                               0.0                  0.0
# 537594                               0.0                 20.0
#
# Description  TOADSTOOL MONEY BOX  WOODEN HEART CHRISTMAS SCANDINAVIAN  \
# InvoiceNo
# 536527                       0.0                                  0.0
# 536840                       0.0                                  0.0
# 536861                       0.0                                  0.0
# 536967                       0.0                                  0.0
# 536983                       0.0                                  0.0
# 537197                       0.0                                  0.0
# 537198                       0.0                                  0.0
# 537201                       0.0                                 12.0
# 537212                       0.0                                  0.0
# 537250                       0.0                                  0.0
# 537594                       6.0                                  0.0
#
# Description  WOODEN STAR CHRISTMAS SCANDINAVIAN  \
# InvoiceNo
# 536527                                      0.0
# 536840                                      0.0
# 536861                                      0.0
# 536967                                      0.0
# 536983                                      0.0
# 537197                                      0.0
# 537198                                      0.0
# 537201                                     12.0
# 537212                                      0.0
# 537250                                      0.0
# 537594                                      0.0
#
# Description  WOODEN TREE CHRISTMAS SCANDINAVIAN  \
# InvoiceNo
# 536527                                      0.0
# 536840                                      0.0
# 536861                                      0.0
# 536967                                      0.0
# 536983                                      0.0
# 537197                                      0.0
# 537198                                      0.0
# 537201                                     24.0
# 537212                                      0.0
# 537250                                      0.0
# 537594                                      0.0
#
# Description  WOODLAND  HEIGHT CHART STICKERS  WOODLAND CHARLOTTE BAG  \
# InvoiceNo
# 536527                                   0.0                     0.0
# 536840                                   0.0                     0.0
# 536861                                   6.0                     0.0
# 536967                                   0.0                     0.0
# 536983                                   0.0                     0.0
# 537197                                   0.0                     0.0
# 537198                                   0.0                     0.0
# 537201                                   0.0                    30.0
# 537212                                   0.0                    10.0
# 537250                                   0.0                     0.0
# 537594                                   0.0                     0.0
#
# Description  WOODLAND PARTY BAG + STICKER SET
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    8.0
# 537197                                    0.0
# 537198                                    0.0
# 537201                                    0.0
# 537212                                    0.0
# 537250                                    0.0
# 537594                                    0.0
#
# [11 rows x 154 columns]

# %% [markdown]
# - unstack : 인덱스 레벨에서 컬럼레벨로 데이터 프레임 변경
# - 쌓은 것을 옆으로 늘어 놓는 개념

# %%
# 0보다 큰 값들을 1로 변경
mybasket = (mybasket > 0).astype(int)
mybasket
# Out:
# Description  3 HOOK HANGER MAGIC GARDEN  3 HOOK PHOTO SHELF ANTIQUE WHITE  \
# InvoiceNo
# 536527                                1                                 0
# 536840                                0                                 0
# 536861                                0                                 0
# 536967                                0                                 0
# 536983                                0                                 1
# 537197                                0                                 0
# 537198                                0                                 0
# 537201                                1                                 0
# 537212                                0                                 0
# 537250                                0                                 0
# 537594                                1                                 0
#
# Description  3 PIECE SPACEBOY COOKIE CUTTER SET  \
# InvoiceNo
# 536527                                        0
# 536840                                        0
# 536861                                        0
# 536967                                        0
# 536983                                        0
# 537197                                        0
# 537198                                        0
# 537201                                        1
# 537212                                        0
# 537250                                        0
# 537594                                        0
#
# Description  5 HOOK HANGER MAGIC TOADSTOOL  5 HOOK HANGER RED MAGIC TOADSTOOL  \
# InvoiceNo
# 536527                                   1                                  1
# 536840                                   0                                  0
# 536861                                   0                                  0
# 536967                                   0                                  0
# 536983                                   0                                  0
# 537197                                   0                                  0
# 537198                                   0                                  0
# 537201                                   1                                  0
# 537212                                   0                                  0
# 537250                                   0                                  0
# 537594                                   0                                  0
#
# Description  6 RIBBONS RUSTIC CHARM  60 CAKE CASES VINTAGE CHRISTMAS  \
# InvoiceNo
# 536527                            0                                0
# 536840                            1                                1
# 536861                            1                                0
# 536967                            0                                0
# 536983                            0                                0
# 537197                            0                                0
# 537198                            0                                0
# 537201                            1                                0
# 537212                            0                                0
# 537250                            0                                0
# 537594                            0                                0
#
# Description  60 TEATIME FAIRY CAKE CASES  ANGEL DECORATION PAINTED ZINC  \
# InvoiceNo
# 536527                                 0                              0
# 536840                                 1                              0
# 536861                                 0                              0
# 536967                                 0                              0
# 536983                                 0                              0
# 537197                                 0                              0
# 537198                                 0                              0
# 537201                                 0                              1
# 537212                                 0                              0
# 537250                                 0                              0
# 537594                                 0                              0
#
# Description  ASSORTED COLOUR LIZARD SUCTION HOOK  ...  STARS GIFT TAPE  \
# InvoiceNo                                         ...
# 536527                                         1  ...                0
# 536840                                         0  ...                0
# 536861                                         0  ...                0
# 536967                                         0  ...                0
# 536983                                         0  ...                0
# 537197                                         0  ...                0
# 537198                                         0  ...                0
# 537201                                         0  ...                0
# 537212                                         0  ...                1
# 537250                                         0  ...                0
# 537594                                         0  ...                0
#
# Description  SWEETHEART CAKESTAND 3 TIER  TEA TIME OVEN GLOVE  \
# InvoiceNo
# 536527                                 0                    0
# 536840                                 1                    0
# 536861                                 0                    0
# 536967                                 0                    0
# 536983                                 0                    0
# 537197                                 0                    0
# 537198                                 0                    0
# 537201                                 0                    0
# 537212                                 0                    0
# 537250                                 0                    0
# 537594                                 0                    1
#
# Description  TOADSTOOL MONEY BOX  WOODEN HEART CHRISTMAS SCANDINAVIAN  \
# InvoiceNo
# 536527                         0                                    0
# 536840                         0                                    0
# 536861                         0                                    0
# 536967                         0                                    0
# 536983                         0                                    0
# 537197                         0                                    0
# 537198                         0                                    0
# 537201                         0                                    1
# 537212                         0                                    0
# 537250                         0                                    0
# 537594                         1                                    0
#
# Description  WOODEN STAR CHRISTMAS SCANDINAVIAN  \
# InvoiceNo
# 536527                                        0
# 536840                                        0
# 536861                                        0
# 536967                                        0
# 536983                                        0
# 537197                                        0
# 537198                                        0
# 537201                                        1
# 537212                                        0
# 537250                                        0
# 537594                                        0
#
# Description  WOODEN TREE CHRISTMAS SCANDINAVIAN  \
# InvoiceNo
# 536527                                        0
# 536840                                        0
# 536861                                        0
# 536967                                        0
# 536983                                        0
# 537197                                        0
# 537198                                        0
# 537201                                        1
# 537212                                        0
# 537250                                        0
# 537594                                        0
#
# Description  WOODLAND  HEIGHT CHART STICKERS  WOODLAND CHARLOTTE BAG  \
# InvoiceNo
# 536527                                     0                       0
# 536840                                     0                       0
# 536861                                     1                       0
# 536967                                     0                       0
# 536983                                     0                       0
# 537197                                     0                       0
# 537198                                     0                       0
# 537201                                     0                       1
# 537212                                     0                       1
# 537250                                     0                       0
# 537594                                     0                       0
#
# Description  WOODLAND PARTY BAG + STICKER SET
# InvoiceNo
# 536527                                      0
# 536840                                      0
# 536861                                      0
# 536967                                      0
# 536983                                      1
# 537197                                      0
# 537198                                      0
# 537201                                      0
# 537212                                      0
# 537250                                      0
# 537594                                      0
#
# [11 rows x 154 columns]

# %% [markdown]
# # Apriori 알고리즘 적용

# %%
my_frequent_itemsets = apriori(mybasket, min_support=0.1, use_colnames=True)
my_frequent_itemsets.head()
# Out:
# C:\Users\choe\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                         itemsets
# 0  0.272727     (3 HOOK HANGER MAGIC GARDEN)
# 1  0.181818  (5 HOOK HANGER MAGIC TOADSTOOL)
# 2  0.272727         (6 RIBBONS RUSTIC CHARM)
# 3  0.181818    (BREAD BIN DINER STYLE IVORY)
# 4  0.181818   (CHILDREN'S CIRCUS PARADE MUG)

# %%
my_rules = association_rules(my_frequent_itemsets, metric='lift', min_threshold=0.1)
my_rules.head()
# Out:
#                        antecedents                      consequents  \
# 0  (5 HOOK HANGER MAGIC TOADSTOOL)     (3 HOOK HANGER MAGIC GARDEN)
# 1     (3 HOOK HANGER MAGIC GARDEN)  (5 HOOK HANGER MAGIC TOADSTOOL)
# 2   (CHILDREN'S CIRCUS PARADE MUG)     (3 HOOK HANGER MAGIC GARDEN)
# 3     (3 HOOK HANGER MAGIC GARDEN)   (CHILDREN'S CIRCUS PARADE MUG)
# 4      (HOT WATER BOTTLE BABUSHKA)     (3 HOOK HANGER MAGIC GARDEN)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.181818            0.272727  0.181818    1.000000  3.666667
# 1            0.272727            0.181818  0.181818    0.666667  3.666667
# 2            0.181818            0.272727  0.181818    1.000000  3.666667
# 3            0.272727            0.181818  0.181818    0.666667  3.666667
# 4            0.181818            0.272727  0.181818    1.000000  3.666667
#
#    leverage  conviction
# 0  0.132231         inf
# 1  0.132231    2.454545
# 2  0.132231         inf
# 3  0.132231    2.454545
# 4  0.132231         inf

# %%
rules = my_rules[['antecedents' ,'consequents', 'support', 'confidence', 'lift']]
rules.head()
# Out:
#                        antecedents                      consequents   support  \
# 0  (5 HOOK HANGER MAGIC TOADSTOOL)     (3 HOOK HANGER MAGIC GARDEN)  0.181818
# 1     (3 HOOK HANGER MAGIC GARDEN)  (5 HOOK HANGER MAGIC TOADSTOOL)  0.181818
# 2   (CHILDREN'S CIRCUS PARADE MUG)     (3 HOOK HANGER MAGIC GARDEN)  0.181818
# 3     (3 HOOK HANGER MAGIC GARDEN)   (CHILDREN'S CIRCUS PARADE MUG)  0.181818
# 4      (HOT WATER BOTTLE BABUSHKA)     (3 HOOK HANGER MAGIC GARDEN)  0.181818
#
#    confidence      lift
# 0    1.000000  3.666667
# 1    0.666667  3.666667
# 2    1.000000  3.666667
# 3    0.666667  3.666667
# 4    1.000000  3.666667

# %%
rules = rules.sort_values('lift', ascending=False)
rules.head()
# Out:
#                                             antecedents  \
# 1711                           (WOODLAND CHARLOTTE BAG)
# 1152  (HOT WATER BOTTLE BABUSHKA, 5 HOOK HANGER MAGI...
# 519                (ROUND SNACK BOXES SET OF4 WOODLAND)
# 520                 (ROUND SNACK BOXES SET OF 4 FRUITS)
# 1130   (JAM MAKING SET PRINTED, WOODLAND CHARLOTTE BAG)
#
#                                             consequents   support  confidence  \
# 1711  (JAM MAKING SET WITH JARS, JAM JAR WITH PINK L...  0.181818         1.0
# 1152  (CHILDREN'S CIRCUS PARADE MUG, 3 HOOK HANGER M...  0.181818         1.0
# 519        (ROUND SNACK BOXES SET OF 4 FRUITS, POSTAGE)  0.181818         1.0
# 520       (ROUND SNACK BOXES SET OF4 WOODLAND, POSTAGE)  0.181818         1.0
# 1130                (JAM MAKING SET WITH JARS, POSTAGE)  0.181818         1.0
#
#       lift
# 1711   5.5
# 1152   5.5
# 519    5.5
# 520    5.5
# 1130   5.5

# %%
rules['antecedents_len'] = rules['antecedents'].apply(lambda x:len(x))
rules['consequents_len'] = rules['consequents'].apply(lambda x:len(x))
rules.head()
# Out:
#                                             antecedents  \
# 1711                           (WOODLAND CHARLOTTE BAG)
# 1152  (HOT WATER BOTTLE BABUSHKA, 5 HOOK HANGER MAGI...
# 519                (ROUND SNACK BOXES SET OF4 WOODLAND)
# 520                 (ROUND SNACK BOXES SET OF 4 FRUITS)
# 1130   (JAM MAKING SET PRINTED, WOODLAND CHARLOTTE BAG)
#
#                                             consequents   support  confidence  \
# 1711  (JAM MAKING SET WITH JARS, JAM JAR WITH PINK L...  0.181818         1.0
# 1152  (CHILDREN'S CIRCUS PARADE MUG, 3 HOOK HANGER M...  0.181818         1.0
# 519        (ROUND SNACK BOXES SET OF 4 FRUITS, POSTAGE)  0.181818         1.0
# 520       (ROUND SNACK BOXES SET OF4 WOODLAND, POSTAGE)  0.181818         1.0
# 1130                (JAM MAKING SET WITH JARS, POSTAGE)  0.181818         1.0
#
#       lift  antecedents_len  consequents_len
# 1711   5.5                1                5
# 1152   5.5                3                2
# 519    5.5                1                2
# 520    5.5                1                2
# 1130   5.5                2                2

# %%
rules[(rules['antecedents_len']>=2) & (rules['support'] >= 0.2) & (rules['lift']>=2)].head()
# Out:
#                                           antecedents  \
# 397   (JAM MAKING SET PRINTED, JAM JAR WITH PINK LID)
# 396  (JAM MAKING SET PRINTED, JAM JAR WITH GREEN LID)
# 398   (JAM JAR WITH GREEN LID, JAM JAR WITH PINK LID)
# 464                  (POSTAGE, JAM JAR WITH PINK LID)
# 462                 (JAM MAKING SET PRINTED, POSTAGE)
#
#                   consequents   support  confidence  lift  antecedents_len  \
# 397  (JAM JAR WITH GREEN LID)  0.363636         1.0  2.75                2
# 396   (JAM JAR WITH PINK LID)  0.363636         1.0  2.75                2
# 398  (JAM MAKING SET PRINTED)  0.363636         1.0  2.75                2
# 464  (JAM MAKING SET PRINTED)  0.363636         1.0  2.75                2
# 462   (JAM JAR WITH PINK LID)  0.363636         1.0  2.75                2
#
#      consequents_len
# 397                1
# 396                1
# 398                1
# 464                1
# 462                1

# %%
rules[rules['consequents']=={'WOODLAND CHARLOTTE BAG'}].head()
# Out:
#                                             antecedents  \
# 1124  (JAM MAKING SET PRINTED, JAM MAKING SET WITH J...
# 498   (JAM MAKING SET PRINTED, JAM MAKING SET WITH J...
# 510                 (JAM MAKING SET WITH JARS, POSTAGE)
# 1083  (JAM MAKING SET PRINTED, JAM MAKING SET WITH J...
# 1111  (JAM MAKING SET WITH JARS, POSTAGE, JAM JAR WI...
#
#                    consequents   support  confidence  lift  antecedents_len  \
# 1124  (WOODLAND CHARLOTTE BAG)  0.181818         1.0   5.5                3
# 498   (WOODLAND CHARLOTTE BAG)  0.181818         1.0   5.5                2
# 510   (WOODLAND CHARLOTTE BAG)  0.181818         1.0   5.5                2
# 1083  (WOODLAND CHARLOTTE BAG)  0.181818         1.0   5.5                3
# 1111  (WOODLAND CHARLOTTE BAG)  0.181818         1.0   5.5                3
#
#       consequents_len
# 1124                1
# 498                 1
# 510                 1
# 1083                1
# 1111                1
